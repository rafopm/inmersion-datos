# %% [markdown]
# <a href="https://colab.research.google.com/github/rafopm/inmersion-datos/blob/main/Inmersi%C3%B3nDeDatos_Aula2-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvenido a nuestro primer encuentro de inmersión de datos.

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# Cantidad de filas vs cantidad de columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 681   Apartamento             Apartamento en venta en Usaquén             3
# 2660  Apartamento      Apartamento en venta en Chapinero Alto             3
# 7053         Casa                       Casa en venta en Bosa             2
# 233   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1902  Apartamento      Apartamento en venta en Barrios Unidos             3
# 5700  Apartamento           Apartamento en venta en El Retiro             3
# 2524  Apartamento            Apartamento en venta en El Chicó             3
# 6757  Apartamento                Apartamento en venta en Bosa             3
# 372   Apartamento            Apartamento en venta en Cedritos             2
# 8353  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 2803  Apartamento            Apartamento en venta en Bosa             3
# 3424         Casa              Casa en venta en Chapinero             5
# 6004  Apartamento        Apartamento en venta en Santa Fe             1
# 5187  Apartamento     Apartamento en venta en Chico Norte             2
# 7586  Apartamento            Apartamento en venta en Suba             3
# ...           ...                                     ...           ...
# 1175  Apartamento       Apartamento en venta en Chapinero             3
# 3748  Apartamento        Apartamento en venta en Cedritos             1
# 5226  Apartamento            Apartamento en venta en Bosa             3
# 7488  Apartamento  Apartamento en venta en Ciudad Salitre             3
# 1492         Casa          Casa en venta en San Cristobal             5
#
#       Banos  Area          Barrio                                     UPZ  \
# ...

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# *Desafío*
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
g = inmuebles.groupby('Barrio')['Area'].mean()
h = g.sort_values(ascending=False)
h.iloc[0:9]
# Out:
# Barrio
# Modelia          4316.750000
# Libertador        642.000000
# Bosa Piamonte     400.000000
# La Soledad        378.625000
# Restrepo          336.500000
# Santa Librada     328.000000
# Las Ferias        320.000000
# Santa Ana         309.375000
# Veraguas          302.666667
# Name: Area, dtype: float64

# %%
h.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# ¿Y si quitamos el valor de Modelia que distorsiona el gráfico?
# Intentemos

# %%
i = h.iloc[1:10]
i
# Out:
# Barrio
# Libertador               642.000000
# Bosa Piamonte            400.000000
# La Soledad               378.625000
# Restrepo                 336.500000
# Santa Librada            328.000000
# Las Ferias               320.000000
# Santa Ana                309.375000
# Veraguas                 302.666667
# Bellavista Occidental    286.200000
# Name: Area, dtype: float64

# %%
i.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
j = inmuebles.groupby('UPZ').agg({
    'Area':'median',
    'Habitaciones':['min', 'max'],
    'Valor': ['min', 'max']
})
j.iloc[0:20]
# Out:
#                                                      Area Habitaciones      \
#                                                    median          min max
# UPZ
# Arborizadora                                         82.0            2   6
# Bolivia                                              53.0            2   4
# Bosa Central                                         47.0            2  12
# Bosa Occidental                                     300.0            2   5
# Boyacá Real                                         104.0            2   9
# Britalia                                             70.0            1   4
# CHAPINERO: Chicó Lago + El Refugio                  122.0            1  16
# CHAPINERO: Pardo Rubio + Chapinero                   84.0            1  32
# CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El Mo...   56.0            1  11
# Casa Blanca Suba                                    136.5            3   3
# ...

# %% [markdown]
# Solución del profe:
# Valor del m2 de cada barrio

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda']=valor[0]
inmuebles['Precio']=valor[1]
inmuebles.sample(10)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 7042  Apartamento  Apartamento en venta en Chico Reservado             2
# 6069  Apartamento    Apartamento en venta en Santa Barbara             1
# 43    Apartamento      Apartamento en venta en El Contador             3
# 587          Casa            Casa en venta en Ciudad Berna             8
# 7768  Apartamento             Apartamento en venta en Suba            10
# 2867  Apartamento             Apartamento en venta en Bosa             3
# 3929  Apartamento     Apartamento en venta en San Patricio             3
# 5532  Apartamento         Apartamento en venta en El Batán             2
# 199   Apartamento      Apartamento en venta en Bella Suiza             3
# 1462  Apartamento          Apartamento en venta en Usaquén             2
#
#       Banos  Area           Barrio                                    UPZ  \
# 7042      3   112  Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# ...

# %% [markdown]
# Quitamos los puntos al número que aun es String

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','', regex = True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# Convertimos el número String a float

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# Disminuir la cantidad de ceros del número:

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Localizar un dato determinado con 110 habitaciones

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 100)

# %% [markdown]
# Importando librerías

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim(50,1000)
plt.ylim(0,20)
plt.savefig('/content/drive/MyDrive/Cursos/inmersion-datos/valor_inmuebles.png',format='png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1. Estudiar mejor el histograma, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
#
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
tipos_a_mostrar = ['Apartamento', 'Casa', 'Oficina/Consultorio'] 
inmuebles_filtrados = inmuebles[inmuebles['Tipo'].isin(tipos_a_mostrar)]

plt.figure(figsize = (10,6))
grafica = sns.histplot(data=inmuebles_filtrados, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim(50,1000)
plt.ylim(0,500)
plt.savefig('/content/drive/MyDrive/Cursos/inmersion-datos/valor_inmuebles_apart_casa_oficina.png',format='png')
plt.show()

# %%
inmuebles['Precio_Millon']/inmuebles['Area']
# Out:
# 0      5.14
# 1      3.94
# 2      7.78
# 3      5.78
# 4      7.58
#        ...
# 9515   4.14
# 9516   6.70
# 9517   2.35
# 9518   1.83
# 9519   2.79
# Length: 9520, dtype: float64

# %%
inmuebles['precio_m2'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.sample(5)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 2146         Casa         Casa en venta en San Cristobal             3      1
# 134   Apartamento       Apartamento en venta en Cedritos             3      2
# 6804         Casa               Casa en venta en Kennedy             5      4
# 1066  Apartamento     Apartamento en venta en Tunjuelito             3      2
# 1962  Apartamento  Apartamento en venta en Puente Aranda             3      2
#
#       Area         Barrio                                             UPZ  \
# 2146    29  San Cristobal                                         Sosiego
# 134     71       Cedritos                                         Usaquén
# 6804   360        Kennedy                                 Kennedy Central
# 1066    72     Tunjuelito                                      Tunjuelito
# 1962    74  Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
#
# ...

# %% [markdown]
# Obtener el precio del m2:

# %%
inmuebles["Valor_m2_Millon"] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  precio_m2  \
# 0    $ 360.000.000      $   360000000         360.00       5.14
# 1    $ 670.000.000      $   670000000         670.00       3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00       7.78
#
#    Valor_m2_Millon
# 0             5.14
# 1             3.94
# 2             7.78

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  precio_m2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00       5.98
# Alhambra                    3.00   2.94 190.41         752.35       4.33
# Andes Norte                 3.00   2.86 124.86         709.57       6.05
# Antonio Nariño              4.31   2.50 163.06         459.22       3.53
# Barrancas                   2.87   2.13  70.20         314.13       4.42
# ...                          ...    ...    ...            ...        ...
# Villa Maria                 4.69   3.69 207.15         402.85       2.04
# Villas De Granada           3.45   2.32  86.59         282.30       3.17
# Villemar                    2.94   2.06  76.89         303.83       3.99
# Zona Franca                 2.00   1.00  54.00         160.00       2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81       4.62
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Millon
# Barrio
# ...

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# ...

# %% [markdown]
# Almacenamos diccionario en variable m2_barrio:

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  precio_m2  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      precio_m2  Valor_m2_Millon  Valor_m2_Barrio
# 0         5.98             5.98             5.98
# 1        73.56            73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      precio_m2  Valor_m2_Millon  Valor_m2_Barrio
# 5      2070.61          2070.61             2.96
# 10     1654.36          1654.36             2.68
# 22     2853.23          2853.23             5.03
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Trabajar con archivos Dane

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Identificaci�n (Cap�tulo A).csv', sep = ';',encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Datos de la vivenda y su entorno (Cap�tulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Condiciones habitacionales del hogar (Cap�tulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Composici�n del hogar y demograf�a (Cap�tulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Educaci�n (Cap�tulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Percepci�n sobre las condiciones de vida y el desempe�o institucional (Cap�tulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Fuerza de trabajo (Cap�tulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-79-01d91e988bec>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Condiciones habitacionales del hogar (Cap�tulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-79-01d91e988bec>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Composici�n del hogar y demograf�a (Cap�tulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-79-01d91e988bec>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Cursos/inmersion-datos/archivos-dane/Educaci�n (Cap�tulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# Out:
# <ipython-input-82-94d5bdd5b9a5>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# Desafío
#
# Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
# Organizar tu notebook para que tu proyecto quede mejor presentado.
